# %% [markdown]
# Fraud-Detection Kaggle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
data = pd.read_csv('insuranceFraud.csv')

# %%
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
data.shape
# Out:
# (1000, 40)

# %%
# Replace "?" values with NAN for imputer
data = data.replace('?', np.nan)

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
dropable_columns = ['policy_number','policy_bind_date','policy_state','insured_zip','incident_location','incident_date','incident_state','incident_city','auto_make','auto_model','auto_year']

# %%
data.drop(dropable_columns,1,inplace=True)

# %%
data.shape
# Out:
# (1000, 29)

# %%
data.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted             0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                 360
# bodily_injuries                   0
# witnesses                         0
# police_report_available         343
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %%
data_mode = dict(data.mode().iloc[0])

# %%
data = data.fillna(data_mode)

# %%
data.describe()
# Out:
#        months_as_customer          age  policy_deductable  \
# count         1000.000000  1000.000000        1000.000000
# mean           203.954000    38.948000        1136.000000
# std            115.113174     9.140287         611.864673
# min              0.000000    19.000000         500.000000
# 25%            115.750000    32.000000         500.000000
# 50%            199.500000    38.000000        1000.000000
# 75%            276.250000    44.000000        2000.000000
# max            479.000000    64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06   25126.100000  -26793.700000
# std               244.167395    2.297407e+06   27872.187708   28104.096686
# min               433.330000   -1.000000e+06       0.000000 -111100.000000
# 25%              1089.607500    0.000000e+00       0.000000  -51500.000000
# 50%              1257.200000    0.000000e+00       0.000000  -23250.000000
# 75%              1415.695000    0.000000e+00   51025.000000       0.000000
# max              2047.590000    1.000000e+07  100500.000000       0.000000
#
#        incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# count               1000.000000                   1000.00000      1000.000000
# mean                  11.644000                      1.83900         0.992000
# std                    6.951373                      1.01888         0.820127
# min                    0.000000                      1.00000         0.000000
# 25%                    6.000000                      1.00000         0.000000
# 50%                   12.000000                      1.00000         1.000000
# 75%                   17.000000                      3.00000         2.000000
# max                   23.000000                      4.00000         2.000000
#
#          witnesses  total_claim_amount  injury_claim  property_claim  \
# count  1000.000000          1000.00000   1000.000000     1000.000000
# mean      1.487000         52761.94000   7433.420000     7399.570000
# std       1.111335         26401.53319   4880.951853     4824.726179
# min       0.000000           100.00000      0.000000        0.000000
# 25%       1.000000         41812.50000   4295.000000     4445.000000
# 50%       1.000000         58055.00000   6775.000000     6750.000000
# 75%       2.000000         70592.50000  11305.000000    10885.000000
# max       3.000000        114920.00000  21450.000000    23670.000000
#
#        vehicle_claim  _c39
# count    1000.000000   0.0
# mean    37928.950000   NaN
# std     18886.252893   NaN
# min        70.000000   NaN
# 25%     30292.500000   NaN
# 50%     42100.000000   NaN
# 75%     50822.500000   NaN
# max     79560.000000   NaN

# %%
data.corr()
# Out:
#                              months_as_customer       age  policy_deductable  \
# months_as_customer                     1.000000  0.922098           0.026807
# age                                    0.922098  1.000000           0.029188
# policy_deductable                      0.026807  0.029188           1.000000
# policy_annual_premium                  0.005018  0.014404          -0.003245
# umbrella_limit                         0.015498  0.018126           0.010870
# capital-gains                          0.006399 -0.007075           0.035212
# capital-loss                           0.020209  0.007368          -0.023544
# incident_hour_of_the_day               0.070639  0.087161           0.060935
# number_of_vehicles_involved            0.014736  0.022102           0.051214
# bodily_injuries                       -0.010162 -0.015679          -0.022765
# witnesses                              0.058383  0.052359           0.066639
# total_claim_amount                     0.062108  0.069863           0.022839
# injury_claim                           0.065329  0.075522           0.039107
# property_claim                         0.034940  0.060898           0.064792
# vehicle_claim                          0.061013  0.062588           0.005269
# _c39                                        NaN       NaN                NaN
#
#                              policy_annual_premium  umbrella_limit  \
# months_as_customer                        0.005018        0.015498
# age                                       0.014404        0.018126
# policy_deductable                        -0.003245        0.010870
# policy_annual_premium                     1.000000       -0.006247
# umbrella_limit                           -0.006247        1.000000
# capital-gains                            -0.013738       -0.047268
# capital-loss                              0.023547       -0.024056
# incident_hour_of_the_day                 -0.001578       -0.023257
# number_of_vehicles_involved              -0.045991       -0.021270
# bodily_injuries                           0.026780        0.022743
# witnesses                                 0.002332       -0.006738
# total_claim_amount                        0.009094       -0.040344
# injury_claim                             -0.017633       -0.045412
# property_claim                           -0.011654       -0.023790
# vehicle_claim                             0.020246       -0.038584
# _c39                                           NaN             NaN
#
#                              capital-gains  capital-loss  \
# months_as_customer                0.006399      0.020209
# age                              -0.007075      0.007368
# policy_deductable                 0.035212     -0.023544
# policy_annual_premium            -0.013738      0.023547
# umbrella_limit                   -0.047268     -0.024056
# capital-gains                     1.000000     -0.046904
# capital-loss                     -0.046904      1.000000
# incident_hour_of_the_day         -0.016406     -0.025054
# number_of_vehicles_involved       0.061643     -0.014895
# bodily_injuries                   0.055829     -0.024418
# witnesses                        -0.017651     -0.041330
# total_claim_amount                0.015980     -0.036060
# injury_claim                      0.025934     -0.046060
# property_claim                   -0.000779     -0.022863
# vehicle_claim                     0.015836     -0.032665
# _c39                                   NaN           NaN
#
#                              incident_hour_of_the_day  \
# months_as_customer                           0.070639
# age                                          0.087161
# policy_deductable                            0.060935
# policy_annual_premium                       -0.001578
# umbrella_limit                              -0.023257
# capital-gains                               -0.016406
# capital-loss                                -0.025054
# incident_hour_of_the_day                     1.000000
# number_of_vehicles_involved                  0.120794
# bodily_injuries                             -0.034563
# witnesses                                    0.006527
# total_claim_amount                           0.217702
# injury_claim                                 0.165768
# property_claim                               0.179536
# vehicle_claim                                0.215626
# _c39                                              NaN
#
#                              number_of_vehicles_involved  bodily_injuries  \
# months_as_customer                              0.014736        -0.010162
# age                                             0.022102        -0.015679
# policy_deductable                               0.051214        -0.022765
# policy_annual_premium                          -0.045991         0.026780
# umbrella_limit                                 -0.021270         0.022743
# capital-gains                                   0.061643         0.055829
# capital-loss                                   -0.014895        -0.024418
# incident_hour_of_the_day                        0.120794        -0.034563
# number_of_vehicles_involved                     1.000000         0.014030
# bodily_injuries                                 0.014030         1.000000
# witnesses                                      -0.014669        -0.005606
# total_claim_amount                              0.274278         0.047093
# injury_claim                                    0.224650         0.047319
# property_claim                                  0.219084         0.039749
# vehicle_claim                                   0.269393         0.043449
# _c39                                                 NaN              NaN
#
#                              witnesses  total_claim_amount  injury_claim  \
# months_as_customer            0.058383            0.062108      0.065329
# age                           0.052359            0.069863      0.075522
# policy_deductable             0.066639            0.022839      0.039107
# policy_annual_premium         0.002332            0.009094     -0.017633
# umbrella_limit               -0.006738           -0.040344     -0.045412
# capital-gains                -0.017651            0.015980      0.025934
# capital-loss                 -0.041330           -0.036060     -0.046060
# incident_hour_of_the_day      0.006527            0.217702      0.165768
# number_of_vehicles_involved  -0.014669            0.274278      0.224650
# bodily_injuries              -0.005606            0.047093      0.047319
# witnesses                     1.000000           -0.011114     -0.024843
# total_claim_amount           -0.011114            1.000000      0.805025
# injury_claim                 -0.024843            0.805025      1.000000
# property_claim                0.052640            0.810686      0.563866
# vehicle_claim                -0.022564            0.982773      0.722878
# _c39                               NaN                 NaN           NaN
#
#                              property_claim  vehicle_claim  _c39
# months_as_customer                 0.034940       0.061013   NaN
# age                                0.060898       0.062588   NaN
# policy_deductable                  0.064792       0.005269   NaN
# policy_annual_premium             -0.011654       0.020246   NaN
# umbrella_limit                    -0.023790      -0.038584   NaN
# capital-gains                     -0.000779       0.015836   NaN
# capital-loss                      -0.022863      -0.032665   NaN
# incident_hour_of_the_day           0.179536       0.215626   NaN
# number_of_vehicles_involved        0.219084       0.269393   NaN
# bodily_injuries                    0.039749       0.043449   NaN
# witnesses                          0.052640      -0.022564   NaN
# total_claim_amount                 0.810686       0.982773   NaN
# injury_claim                       0.563866       0.722878   NaN
# property_claim                     1.000000       0.732090   NaN
# vehicle_claim                      0.732090       1.000000   NaN
# _c39                                    NaN            NaN   NaN

# %%
plt.figure(figsize=(15,15))
ax = sns.heatmap(data.corr(),linewidths=.5,square=True,center=0,annot=True)

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'fraud_reported',
#        '_c39'],
#       dtype='object')

# %%
f, ax = plt.subplots(figsize=(18, 8))
sns.countplot(x='insured_hobbies',hue='fraud_reported',data=data)
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='count'>

# %%
sns.countplot(x='fraud_reported',data=data)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
cat_df = data.select_dtypes(include=['object']).copy()

# %%
num_df = data.select_dtypes(include=["int64"]).copy()

# %%
cat_df.head()
# Out:
#   policy_csl insured_sex insured_education_level insured_occupation  \
# 0    250/500        MALE                      MD       craft-repair
# 1    250/500        MALE                      MD  machine-op-inspct
# 2    100/300      FEMALE                     PhD              sales
# 3    250/500      FEMALE                     PhD       armed-forces
# 4   500/1000        MALE               Associate              sales
#
#   insured_hobbies insured_relationship             incident_type  \
# 0        sleeping              husband  Single Vehicle Collision
# 1         reading       other-relative             Vehicle Theft
# 2     board-games            own-child   Multi-vehicle Collision
# 3     board-games            unmarried  Single Vehicle Collision
# 4     board-games            unmarried             Vehicle Theft
#
#     collision_type incident_severity authorities_contacted property_damage  \
# 0   Side Collision      Major Damage                Police             YES
# 1   Rear Collision      Minor Damage                Police              NO
# 2   Rear Collision      Minor Damage                Police              NO
# 3  Front Collision      Major Damage                Police              NO
# 4   Rear Collision      Minor Damage                  None              NO
#
#   police_report_available fraud_reported
# 0                     YES              Y
# 1                      NO              Y
# 2                      NO              N
# 3                      NO              Y
# 4                      NO              N

# %%
cat_df.columns
# Out:
# Index(['policy_csl', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'property_damage', 'police_report_available',
#        'fraud_reported'],
#       dtype='object')

# %%
for column in cat_df.columns:
    le = LabelEncoder()
    cat_df[column] = le.fit_transform(cat_df[column])

# %%
cat_df.head()
# Out:
#    policy_csl  insured_sex  insured_education_level  insured_occupation  \
# 0           1            1                        4                   2
# 1           1            1                        4                   6
# 2           0            0                        6                  11
# 3           1            0                        6                   1
# 4           2            1                        0                  11
#
#    insured_hobbies  insured_relationship  incident_type  collision_type  \
# 0               17                     0              2               2
# 1               15                     2              3               1
# 2                2                     3              0               1
# 3                2                     4              2               0
# 4                2                     4              3               1
#
#    incident_severity  authorities_contacted  property_damage  \
# 0                  0                      4                1
# 1                  1                      4                0
# 2                  1                      4                0
# 3                  0                      4                0
# 4                  1                      2                0
#
#    police_report_available  fraud_reported
# 0                        1               1
# 1                        0               1
# 2                        0               0
# 3                        0               1
# 4                        0               0

# %%
num_df.head()
# Out:
#    months_as_customer  age  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328   48               1000               0          53300
# 1                 228   42               2000         5000000              0
# 2                 134   29               2000         5000000          35100
# 3                 256   41               2000         6000000          48900
# 4                 228   44               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 0                1          2               71610          6510
# 1                0          0                5070           780
# 2                2          3               34650          7700
# 3                1          2               63400          6340
# 4                0          1                6500          1300
#
#    property_claim  vehicle_claim
# 0           13020          52080
# 1             780           3510
# 2            3850          23100
# 3            6340          50720
# 4             650           4550

# %%
final_df = pd.concat([num_df,cat_df], axis=1)

# %%
final_df.head()
# Out:
#    months_as_customer  age  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328   48               1000               0          53300
# 1                 228   42               2000         5000000              0
# 2                 134   29               2000         5000000          35100
# 3                 256   41               2000         6000000          48900
# 4                 228   44               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  ...  insured_occupation  insured_hobbies  \
# 0                1          2  ...                   2               17
# 1                0          0  ...                   6               15
# 2                2          3  ...                  11                2
# 3                1          2  ...                   1                2
# 4                0          1  ...                  11                2
#
#    insured_relationship  incident_type  collision_type  incident_severity  \
# 0                     0              2               2                  0
# 1                     2              3               1                  1
# 2                     3              0               1                  1
# 3                     4              2               0                  0
# 4                     4              3               1                  1
#
#    authorities_contacted  property_damage  police_report_available  \
# 0                      4                1                        1
# 1                      4                0                        0
# 2                      4                0                        0
# 3                      4                0                        0
# 4                      2                0                        0
#
#    fraud_reported
# 0               1
# 1               1
# 2               0
# 3               1
# 4               0
#
# [5 rows x 27 columns]

# %%
target_value = 'fraud_reported'
X = final_df.drop([target_value],1)
y = final_df[target_value]

# %%
train_X, test_X , train_y, test_y = train_test_split(X, y, test_size =0.3, random_state = 2020) #split data into train and test

# %% [markdown]
# # Train The Model
#
#
# RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=100)

# %%
pred_y = clf.fit(train_X, train_y).predict(test_X)

# %%
accuracy_score(test_y, pred_y)
# Out:
# 0.7633333333333333

# %%
confusion_matrix(test_y, pred_y)
# Out:
# array([[197,  31],
#        [ 40,  32]], dtype=int64)

# %%
roc_auc_score(test_y, pred_y)
# Out:
# 0.6542397660818713

# %%
#ROC curve
fpr, tpr, threshold = metrics.roc_curve(test_y, pred_y)
roc_auc = metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Support Vector Classifier

# %%
clf2 = SVC()

# %%
pred2_y = clf2.fit(train_X, train_y).predict(test_X)

# %%
accuracy_score(test_y, pred2_y)
# Out:
# 0.76

# %%
confusion_matrix(test_y, pred2_y)
# Out:
# array([[228,   0],
#        [ 72,   0]], dtype=int64)

# %%
roc_auc_score(test_y, pred2_y)
# Out:
# 0.5

# %% [markdown]
# GridSearchCv For Better Accuracy

# %%
param_grid = {"kernel": ['rbf','sigmoid'],
             "C":[0.1,0.5,1.0],
             "random_state":[0,10,20,30]}

# %%
grid = GridSearchCV(estimator=clf2, param_grid=param_grid, cv=5,  verbose=3)

# %%
grid.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END .C=0.1, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 2/5] END .C=0.1, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END .C=0.1, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END .C=0.1, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END .C=0.1, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 1/5] END .C=0.5, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 2/5] END .C=0.5, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END .C=0.5, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END .C=0.5, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END .C=0.5, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=sigmoid, random_state=0;, score=0.743 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=sigmoid, random_state=10;, score=0.743 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=sigmoid, random_state=20;, score=0.743 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 1/5] END C=0.5, kernel=sigmoid, random_state=30;, score=0.743 total time=   0.0s
# [CV 2/5] END C=0.5, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.5, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=0.5, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.5, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 1/5] END .C=1.0, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 2/5] END .C=1.0, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END .C=1.0, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END .C=1.0, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END .C=1.0, kernel=rbf, random_state=0;, score=0.750 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=rbf, random_state=10;, score=0.750 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=rbf, random_state=20;, score=0.750 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=rbf, random_state=30;, score=0.750 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=sigmoid, random_state=0;, score=0.743 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=sigmoid, random_state=0;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=sigmoid, random_state=0;, score=0.757 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=sigmoid, random_state=10;, score=0.743 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=sigmoid, random_state=10;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=sigmoid, random_state=10;, score=0.757 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=sigmoid, random_state=20;, score=0.743 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=sigmoid, random_state=20;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=sigmoid, random_state=20;, score=0.757 total time=   0.0s
# [CV 1/5] END C=1.0, kernel=sigmoid, random_state=30;, score=0.743 total time=   0.0s
# [CV 2/5] END C=1.0, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 3/5] END C=1.0, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 4/5] END C=1.0, kernel=sigmoid, random_state=30;, score=0.750 total time=   0.0s
# [CV 5/5] END C=1.0, kernel=sigmoid, random_state=30;, score=0.757 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 0.5, 1.0], 'kernel': ['rbf', 'sigmoid'],
#                          'random_state': [0, 10, 20, 30]},
#              verbose=3)

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, random_state=0)
